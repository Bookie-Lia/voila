# %% [markdown]
# # INTRO TO PYTHON - TAKE HOME EXAM

# %%
import IPython
from ipywidgets import AppLayout
from ipywidgets import widgets
from ipywidgets import TwoByTwoLayout

# %%
out = widgets.Output(layout={'border': '1px solid cyan'})
out
# Out:
# Output(layout=Layout(border='1px solid cyan'))

# %%
with out:
  print('Hello user!')
  print(' ')
  print('This app was authored by:')
  print('- Giulia Webers (i6272810)')
  print('- Joelle Mona (istudentID)')

# %%
from IPython.display import Image

url='https://img.freepik.com/premium-vector/coder-developer-concentrated-working-project-developing-programming-coding-technologies_569013-336.jpg'
image = IPython.display.Image(url, width = 300)
center_output=widgets.Image(
  value=image.data,
  format='jpg', 
  width=300,
  height=400,
)

AppLayout(center=center_output)
# Out:
# AppLayout(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb…

# %% [markdown]
# #1. INTRODUCTION
#
# For this take home exam, the "Worldwide covid data" dataset was examined.
#
# This notebook will analyze whether covid vaccinations significantly helped curbe the progression of the covid-19 pandemic in (insert continent).
#
# This will be done by firstly analyzing the progression of the vaccination count. Then, the effect of increasing vaccinations on the number of covid cases will be explored. Additionally, the potential correlation between the number of covid vaccins, number of covid cases and number of death casesa will be analyzed.

# %% [markdown]
# # **RESEARCH QUESTION**
# ## *Did the vaccinations against covid significantly curbe the progression of the covid-19 pandemic in North America?*
#
# STEP OF ANALYSIS
#
# > Progression of the vaccination count
#
#
# > What was the effect of vaccines on covid cases?
#
#
# > What was the effect of vaccines on the cases of death?

# %% [markdown]
# # 2. DATA PREPARATION

# %% [markdown]
# LOADING THE DATASET

# %%
import pandas as pd
import numpy as np
import datetime

covid = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv", parse_dates=['date'])
covid.shape
# Out:
# (262423, 67)

# %% [markdown]
# The dataset was subsequantially briefly analyzed.

# %%
col = covid.columns
print(col)
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'population',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %%
covid.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0           NaN                  37.746                         0.5
# 1           NaN                  37.746                         0.5
# 2           NaN                  37.746                         0.5
# 3           NaN                  37.746                         0.5
# 4           NaN                  37.746                         0.5
#
#    life_expectancy  human_development_index  population  \
# 0            64.83                    0.511  41128772.0
# 1            64.83                    0.511  41128772.0
# 2            64.83                    0.511  41128772.0
# 3            64.83                    0.511  41128772.0
# 4            64.83                    0.511  41128772.0
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# *Observation:* The initial dataset has a lot of columns and quite many NaN values, so it will need some tweaking before usage.

# %%
all_continents=covid['continent'].unique()
all_continents
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
df2 = covid.pivot_table(columns=['continent'], aggfunc='size')
print (df2)
# Out:
# continent
# Africa           59603
# Asia             55674
# Europe           59995
# North America    39417
# Oceania          18719
# South America    14288
# dtype: int64

# %%
data=covid.loc[covid.continent == 'North America', ['iso_code', 'location', 
                                                    'total_vaccinations', 
                                                    'people_vaccinated', 
                                                    'people_fully_vaccinated', 
                                                    'total_cases_per_million',
                                                    'new_cases_smoothed',
                                                    'new_deaths_per_million',
                                                    'icu_patients',
                                                    'date']]

# %% [markdown]
# *Information:* We have now selected our continent of choice, North America, and our columns of interest.

# %% [markdown]
# # EXPLORATION & CLEANING OF THE DATA

# %% [markdown]
# Now we will explore and cleane our new dataframe.

# %%
print('These are the columns of interest')
col = data.columns
print(col)
# Out:
# These are the columns of interest
# Index(['iso_code', 'location', 'total_vaccinations', 'people_vaccinated',
#        'people_fully_vaccinated', 'total_cases_per_million',
#        'new_cases_smoothed', 'new_deaths_per_million', 'icu_patients', 'date'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# iso_code                       0
# location                       0
# total_vaccinations         31392
# people_vaccinated          31534
# people_fully_vaccinated    31818
# total_cases_per_million     2388
# new_cases_smoothed          2604
# new_deaths_per_million      6667
# icu_patients               37389
# date                           0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39417 entries, 6625 to 248633
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   iso_code                 39417 non-null  object
#  1   location                 39417 non-null  object
#  2   total_vaccinations       8025 non-null   float64
#  3   people_vaccinated        7883 non-null   float64
#  4   people_fully_vaccinated  7599 non-null   float64
#  5   total_cases_per_million  37029 non-null  float64
#  6   new_cases_smoothed       36813 non-null  float64
#  7   new_deaths_per_million   32750 non-null  float64
#  8   icu_patients             2028 non-null   float64
#  9   date                     39417 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), object(2)
# memory usage: 3.3+ MB

# %% [markdown]
# *Observation:* Total_vaccinations, people_vaccinated, people_fully_vaccinated has high null count because vaccinations started late.
# Death count is also initially zero at start.

# %%
data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        8.025000e+03       7.883000e+03             7.599000e+03
# mean         5.981543e+07       2.773156e+07             2.433277e+07
# std          1.493381e+08       6.754080e+07             5.893195e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.600120e+05       8.775200e+04             7.791750e+04
# 50%          1.444171e+06       7.522190e+05             7.018810e+05
# 75%          2.976927e+07       1.062025e+07             9.900206e+06
# max          6.720761e+08       2.695541e+08             2.300759e+08
#
#        total_cases_per_million  new_cases_smoothed  new_deaths_per_million  \
# count             37029.000000        36813.000000            32750.000000
# mean              77789.472253         3327.619231                1.519320
# std              106649.970081        25556.008468                8.841352
# min                   0.003000            0.000000                0.000000
# 25%                2718.777000            0.571000                0.000000
# 50%               31845.405000           13.857000                0.000000
# 75%              107820.725000          209.000000                0.624000
# max              586576.041000       806961.429000              554.204000
#
#        icu_patients
# count   2028.000000
# mean    5128.392012
# std     7326.104001
# min       42.000000
# 25%      315.500000
# 50%     1132.000000
# 75%     8010.000000
# max    28891.000000

# %%
data.describe(include=['object'])
# Out:
#        iso_code location
# count     39417    39417
# unique       37       37
# top         MEX   Mexico
# freq       1162     1162

# %%
#checking iso codes
all_iso_codes=data['iso_code'].unique()
all_iso_codes
# Out:
# array(['AIA', 'ATG', 'ABW', 'BHS', 'BRB', 'BLZ', 'BMU', 'BES', 'VGB',
#        'CAN', 'CYM', 'CRI', 'CUB', 'CUW', 'DMA', 'DOM', 'SLV', 'GRL',
#        'GRD', 'GTM', 'HTI', 'HND', 'JAM', 'MEX', 'MSR', 'NIC', 'PAN',
#        'PRI', 'KNA', 'LCA', 'SPM', 'VCT', 'SXM', 'TTO', 'TCA', 'USA',
#        'VIR'], dtype=object)

# %%
#checking location
all_continents=data['location'].unique()
all_continents
# Out:
# array(['Anguilla', 'Antigua and Barbuda', 'Aruba', 'Bahamas', 'Barbados',
#        'Belize', 'Bermuda', 'Bonaire Sint Eustatius and Saba',
#        'British Virgin Islands', 'Canada', 'Cayman Islands', 'Costa Rica',
#        'Cuba', 'Curacao', 'Dominica', 'Dominican Republic', 'El Salvador',
#        'Greenland', 'Grenada', 'Guatemala', 'Haiti', 'Honduras',
#        'Jamaica', 'Mexico', 'Montserrat', 'Nicaragua', 'Panama',
#        'Puerto Rico', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines',
#        'Sint Maarten (Dutch part)', 'Trinidad and Tobago',
#        'Turks and Caicos Islands', 'United States',
#        'United States Virgin Islands'], dtype=object)

# %% [markdown]
# The following figure visually represent how much the particular location is repeated in the dataset

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#sort data by date
data.sort_values(by='date', inplace = True) 
data.head(5)
# Out:
#        iso_code location  total_vaccinations  people_vaccinated  \
# 149861      MEX   Mexico                 NaN                NaN
# 149862      MEX   Mexico                 NaN                NaN
# 149863      MEX   Mexico                 NaN                NaN
# 149864      MEX   Mexico                 NaN                NaN
# 149865      MEX   Mexico                 NaN                NaN
#
#         people_fully_vaccinated  total_cases_per_million  new_cases_smoothed  \
# 149861                      NaN                      NaN                 NaN
# 149862                      NaN                      NaN                 NaN
# 149863                      NaN                      NaN                 NaN
# 149864                      NaN                      NaN                 NaN
# 149865                      NaN                      NaN                 NaN
#
#         new_deaths_per_million  icu_patients       date
# 149861                     NaN           NaN 2020-01-01
# 149862                     NaN           NaN 2020-01-02
# 149863                     NaN           NaN 2020-01-03
# 149864                     NaN           NaN 2020-01-04
# 149865                     NaN           NaN 2020-01-05

# %%
data.tail(5)
# Out:
#        iso_code             location  total_vaccinations  people_vaccinated  \
# 96119       GTM            Guatemala                 NaN                NaN
# 8789        ATG  Antigua and Barbuda                 NaN                NaN
# 17744       BHS              Bahamas                 NaN                NaN
# 103389      HND             Honduras                 NaN                NaN
# 94175       GRD              Grenada                 NaN                NaN
#
#         people_fully_vaccinated  total_cases_per_million  new_cases_smoothed  \
# 96119                       NaN                69367.573             197.571
# 8789                        NaN                97107.879               0.000
# 17744                       NaN                91443.917               0.000
# 103389                      NaN                45265.641              19.143
# 94175                       NaN               156863.995               0.000
#
#         new_deaths_per_million  icu_patients       date
# 96119                    0.112           NaN 2023-03-07
# 8789                     0.000           NaN 2023-03-07
# 17744                    0.000           NaN 2023-03-07
# 103389                   0.000           NaN 2023-03-07
# 94175                    0.000           NaN 2023-03-07

# %%
print('Data point starts from ',data.date.min(),'n')
print('Data point ends at ',data.date.max(),'n')
# Out:
# Data point starts from  2020-01-01 00:00:00 n
# Data point ends at  2023-03-07 00:00:00 n

# %% [markdown]
# Dates go from January 2020 to February 2023

# %% [markdown]
# 29th March 2022 stopped keeping track of vaccinations

# %%
#removing rows that only have NaN values
df2=data.dropna(thresh=4)

# %% [markdown]
# Rows that only have NaN values for 'total_vaccinations', people_vaccinated' ,'people_fully_vaccinated', 'new_deaths_per_million','new_cases_smoothed' were dropped. Additionally, NaN values were replaced by 0.

# %%
# Replacing our NaN values with 0
clean_df= data
clean_df[['total_vaccinations', 'people_vaccinated', 
          'people_fully_vaccinated', 'new_deaths_per_million', 
          'new_cases_smoothed']] = clean_df[['total_vaccinations', 
                                             'people_vaccinated', 
                                             'people_fully_vaccinated', 
                                             'new_deaths_per_million',
                                             'new_cases_smoothed']].fillna(0)

# %%
#creating month_year
clean_df['month_year'] = clean_df['date'].dt.strftime('%b-%Y')
clean_df = clean_df.set_index('month_year') 

clean_df = clean_df.drop(['date'], axis=1)

clean_df.head()
# Out:
#            iso_code location  total_vaccinations  people_vaccinated  \
# month_year
# Jan-2020        MEX   Mexico                 0.0                0.0
# Jan-2020        MEX   Mexico                 0.0                0.0
# Jan-2020        MEX   Mexico                 0.0                0.0
# Jan-2020        MEX   Mexico                 0.0                0.0
# Jan-2020        MEX   Mexico                 0.0                0.0
#
#             people_fully_vaccinated  total_cases_per_million  \
# month_year
# Jan-2020                        0.0                      NaN
# Jan-2020                        0.0                      NaN
# Jan-2020                        0.0                      NaN
# Jan-2020                        0.0                      NaN
# Jan-2020                        0.0                      NaN
#
#             new_cases_smoothed  new_deaths_per_million  icu_patients
# month_year
# Jan-2020                   0.0                     0.0           NaN
# Jan-2020                   0.0                     0.0           NaN
# Jan-2020                   0.0                     0.0           NaN
# Jan-2020                   0.0                     0.0           NaN
# Jan-2020                   0.0                     0.0           NaN

# %%
print (clean_df.dtypes)
# Out:
# iso_code                    object
# location                    object
# total_vaccinations         float64
# people_vaccinated          float64
# people_fully_vaccinated    float64
# total_cases_per_million    float64
# new_cases_smoothed         float64
# new_deaths_per_million     float64
# icu_patients               float64
# dtype: object

# %%
#grouping data by country and month & year
data_grouped= clean_df.groupby(['location', 'iso_code', 'month_year']).agg({"total_vaccinations":"max",
                                                            "people_vaccinated":"max",
                                                            "people_fully_vaccinated":"max", 
                                                            "total_cases_per_million":"max",
                                                            'new_deaths_per_million':"sum",
                                                            'new_cases_smoothed':'sum'})

data_grouped.head()
# Out:
#                               total_vaccinations  people_vaccinated  \
# location iso_code month_year
# Anguilla AIA      Apr-2020                   0.0                0.0
#                   Apr-2021                6898.0             6115.0
#                   Apr-2022               23126.0            10622.0
#                   Aug-2020                   0.0                0.0
#                   Aug-2021               18458.0             9493.0
#
#                               people_fully_vaccinated  \
# location iso_code month_year
# Anguilla AIA      Apr-2020                        0.0
#                   Apr-2021                      783.0
#                   Apr-2022                     9874.0
#                   Aug-2020                        0.0
#                   Aug-2021                     8965.0
#
#                               total_cases_per_million  new_deaths_per_million  \
# location iso_code month_year
# Anguilla AIA      Apr-2020                    188.953                     0.0
#                   Apr-2021                   5857.530                     0.0
#                   Apr-2022                 175599.924                     0.0
#                   Aug-2020                    188.953                     0.0
#                   Aug-2021                  13667.569                     0.0
#
#                               new_cases_smoothed
# location iso_code month_year
# Anguilla AIA      Apr-2020                 1.573
#                   Apr-2021                55.857
#                   Apr-2022               100.431
#                   Aug-2020                 0.000
#                   Aug-2021                85.715

# %%
data_grouped.sort_values(by='month_year', inplace = True) 
data_grouped.head(5)
# Out:
#                                          total_vaccinations  \
# location            iso_code month_year
# Anguilla            AIA      Apr-2020                   0.0
# Antigua and Barbuda ATG      Apr-2020                   0.0
# Puerto Rico         PRI      Apr-2020                   0.0
# Panama              PAN      Apr-2020                   0.0
# Nicaragua           NIC      Apr-2020                   0.0
#
#                                          people_vaccinated  \
# location            iso_code month_year
# Anguilla            AIA      Apr-2020                  0.0
# Antigua and Barbuda ATG      Apr-2020                  0.0
# Puerto Rico         PRI      Apr-2020                  0.0
# Panama              PAN      Apr-2020                  0.0
# Nicaragua           NIC      Apr-2020                  0.0
#
#                                          people_fully_vaccinated  \
# location            iso_code month_year
# Anguilla            AIA      Apr-2020                        0.0
# Antigua and Barbuda ATG      Apr-2020                        0.0
# Puerto Rico         PRI      Apr-2020                        0.0
# Panama              PAN      Apr-2020                        0.0
# Nicaragua           NIC      Apr-2020                        0.0
#
#                                          total_cases_per_million  \
# location            iso_code month_year
# Anguilla            AIA      Apr-2020                    188.953
# Antigua and Barbuda ATG      Apr-2020                    255.940
# Puerto Rico         PRI      Apr-2020                        NaN
# Panama              PAN      Apr-2020                   1481.656
# Nicaragua           NIC      Apr-2020                      1.871
#
#                                          new_deaths_per_million  \
# location            iso_code month_year
# Anguilla            AIA      Apr-2020                     0.000
# Antigua and Barbuda ATG      Apr-2020                    31.992
# Puerto Rico         PRI      Apr-2020                     0.000
# Panama              PAN      Apr-2020                    35.839
# Nicaragua           NIC      Apr-2020                     0.288
#
#                                          new_cases_smoothed
# location            iso_code month_year
# Anguilla            AIA      Apr-2020                 1.573
# Antigua and Barbuda ATG      Apr-2020                17.571
# Puerto Rico         PRI      Apr-2020                 0.000
# Panama              PAN      Apr-2020              5153.572
# Nicaragua           NIC      Apr-2020                 9.435

# %%
data_grouped.shape
# Out:
# (1341, 6)

# %%
#moving index to columns
data_grouped = data_grouped.reset_index()

# %%
data_grouped.dtypes
# Out:
# location                    object
# iso_code                    object
# month_year                  object
# total_vaccinations         float64
# people_vaccinated          float64
# people_fully_vaccinated    float64
# total_cases_per_million    float64
# new_deaths_per_million     float64
# new_cases_smoothed         float64
# dtype: object

# %%
#turning month_year into a datetime variable
data_grouped.month_year = pd.to_datetime(data_grouped.month_year)

# %%
#cheching if it worked
data_grouped.dtypes
# Out:
# location                           object
# iso_code                           object
# month_year                 datetime64[ns]
# total_vaccinations                float64
# people_vaccinated                 float64
# people_fully_vaccinated           float64
# total_cases_per_million           float64
# new_deaths_per_million            float64
# new_cases_smoothed                float64
# dtype: object

# %% [markdown]
# # DESCRIPTION AND VISUALISATION OF THE DATA

# %%
import altair as alt
import ipywidgets as widgets
from ipywidgets import interact
from ipywidgets import fixed

# %%
#cheching if the chart works
chart1= alt.Chart(data_grouped).mark_point().encode(
      x=alt.X('month_year:T', title='Time'),
      y=alt.Y('total_vaccinations:Q',title='Total vaccinations count'),
      tooltip=['location', 'total_vaccinations'],
      color='location'
).properties(title='Covid vaccinations over time - all countries'
)
chart1
# Out:
# alt.Chart(...)

# %%
def select_country_data(iso_code, df):
   return df.loc[df['iso_code'] == iso_code, ]

# %%
def visualize_country_data(iso_code, df):
  
  country_data = select_country_data(iso_code, df)

  chart= alt.Chart(country_data).mark_point().encode(
      x=alt.X('month_year:T', title='Time'),
      y=alt.Y('total_vaccinations',title='Total vaccinations count'),
      tooltip=['location', 'total_vaccinations'],
  ).properties(title='Covid vaccinations over time per country'
  )
  display(chart)

# %%
all_iso_codes=clean_df['iso_code'].unique()
all_iso_codes
# Out:
# array(['MEX', 'USA', 'CAN', 'GTM', 'DOM', 'PRI', 'CRI', 'PAN', 'HND',
#        'JAM', 'CUB', 'ABW', 'ATG', 'CYM', 'VCT', 'LCA', 'CUW', 'TTO',
#        'BHS', 'GRL', 'BRB', 'MSR', 'BMU', 'NIC', 'SLV', 'HTI', 'GRD',
#        'DMA', 'BLZ', 'VIR', 'KNA', 'VGB', 'AIA', 'TCA', 'BES', 'SPM',
#        'SXM'], dtype=object)

# %%
chart2=interact(visualize_country_data, iso_code= all_iso_codes, df=fixed(data_grouped)); 
chart2
# Out:
# interactive(children=(Dropdown(description='iso_code', options=('MEX', 'USA', 'CAN', 'GTM', 'DOM', 'PRI', 'CRI…
# <function __main__.visualize_country_data(iso_code, df)>

# %%
#cheking if the chart works
chart1= alt.Chart(data_grouped).mark_point().encode(
      x=alt.X('month_year:T', title='Time'),
      y=alt.Y('total_vaccinations:Q',title='Total vaccinations count'),
      tooltip=['location', 'total_vaccinations'],
      color='new_deaths_per_million'
).properties(title='Covid vaccinations over time - all countries'
)
chart1
# Out:
# alt.Chart(...)

# %%
base = alt.Chart(data_grouped).encode(
    alt.X('month_year:T', axis=alt.Axis(title='Time'))
).properties(title='Covid vaccinations & new deaths over time - North America')


point1 = base.mark_point(stroke='#57A44C', interpolate='monotone').encode(
    alt.Y('total_vaccinations',
          axis=alt.Axis(title=' Total vaccinations', titleColor='#57A44C'))
)

point2 = base.mark_point(stroke='#5276A7', interpolate='monotone').encode(
    alt.Y('new_deaths_per_million',
          axis=alt.Axis(title='New deaths per million', titleColor='#5276A7'))
)


alt.layer(point1, point2).resolve_scale(
    y = 'independent'
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# *Observe:* except for certain otliers were  new deaths per million and new cases spiked, there is a decreasing trend with increasing covid vaccination counts.

# %%
base = alt.Chart(data_grouped).encode(
    alt.X('month_year:T', axis=alt.Axis(title='Time'))
).properties(title='Covid vaccinations & new cases over time - North America')


point1 = base.mark_point(stroke='#57A44C', interpolate='monotone').encode(
    alt.Y('total_vaccinations',
          axis=alt.Axis(title=' Total vaccinations', titleColor='#57A44C'))
)

point2 = base.mark_point(stroke='#5276A7', interpolate='monotone').encode(
    alt.Y('new_cases_smoothed',
          axis=alt.Axis(title='New cases (smoothed)', titleColor='#5276A7'))
)


alt.layer(point1, point2).resolve_scale(
    y = 'independent'
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Let's observe the total case per million trend with increasing vaccinatio  count:

# %%
base = alt.Chart(data_grouped).encode(x='month_year:O').properties(title='Total vaccinations & new cases over time - North America')

bar = base.mark_bar().encode(y='total_vaccinations:Q')

line =  base.mark_line(color='red').encode(
    y='total_cases_per_million:Q'
)

(bar + line).properties(width=600)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# And here is the progression of total cases per million on it's own. Note how it suddedly shows more variation than when plotted with increasing vaccination count.

# %%
base = alt.Chart(data_grouped).encode(x='month_year:O').properties(title= 'Total covid cases (per million) over time')

bar = base.mark_bar(color='red').encode(y='total_cases_per_million:Q')
(bar).properties(width=600)
# Out:
# alt.Chart(...)

# %% [markdown]
# Let's represent the progression of new_deaths_per million: there is a decreasing trend towards later dates.

# %%
base = alt.Chart(data_grouped).encode(x='month_year:O').properties(title= 'Progression of new deaths (per million) over time')

bar = base.mark_bar().encode(y='new_deaths_per_million:Q')
(bar).properties(width=600)
# Out:
# alt.Chart(...)

# %%
#total vaccinated till date
country_wise_total_vaccinated = {}
for location in data_grouped.location.unique() : 
    vaccinated = 0
    for i in range(len(data_grouped)) : 
        if data_grouped.location[i] == location : 
            vaccinated += data_grouped.people_vaccinated[i]
    country_wise_total_vaccinated[location] = vaccinated 
#     made a seperate dict from the df 
    country_wise_total_vaccinated_df = pd.DataFrame.from_dict(country_wise_total_vaccinated,
                                                         orient='index',
                                                         columns = ['total_vaccinated_till_date'])
#     converted dict to df 
country_wise_total_vaccinated_df.sort_values(by = 'total_vaccinated_till_date', ascending = False, inplace = True)
country_wise_total_vaccinated_df
# Out:
#                                   total_vaccinated_till_date
# United States                                   5.694158e+09
# Mexico                                          1.472306e+09
# Canada                                          7.109598e+08
# Cuba                                            2.137693e+08
# Dominican Republic                              1.567927e+08
# Guatemala                                       1.546883e+08
# Honduras                                        1.004899e+08
# Nicaragua                                       9.364179e+07
# Costa Rica                                      7.688898e+07
# Panama                                          6.698329e+07
# El Salvador                                     6.416246e+07
# Jamaica                                         1.496936e+07
# Trinidad and Tobago                             1.063220e+07
# Belize                                          5.070618e+06
# Haiti                                           3.558613e+06
# Barbados                                        3.430002e+06
# Bahamas                                         2.361103e+06
# Curacao                                         2.043857e+06
# Aruba                                           2.023013e+06
# Cayman Islands                                  1.232993e+06
# Saint Lucia                                     9.439680e+05
# Antigua and Barbuda                             8.839740e+05
# Saint Vincent and the Grenadines                6.992410e+05
# Grenada                                         6.966550e+05
# Bermuda                                         6.592770e+05
# Dominica                                        5.279010e+05
# Sint Maarten (Dutch part)                       4.814760e+05
# Turks and Caicos Islands                        4.695940e+05
# Greenland                                       3.780680e+05
# Saint Kitts and Nevis                           3.745370e+05
# British Virgin Islands                          2.834070e+05
# Anguilla                                        2.417310e+05
# Montserrat                                      3.687100e+04
# Bonaire Sint Eustatius and Saba                 2.483500e+04
# United States Virgin Islands                    0.000000e+00
# Saint Pierre and Miquelon                       0.000000e+00
# Puerto Rico                                     0.000000e+00

# %%
import plotly.express as px

fig = px.bar(country_wise_total_vaccinated_df, 
             y = 'total_vaccinated_till_date',
             x = country_wise_total_vaccinated_df.index,
             color = 'total_vaccinated_till_date',
             color_discrete_sequence= px.colors.sequential.Viridis_r
            )
fig.update_layout(
    title={
            'text' : "Vaccination till date in various countries",
            'y':0.95,
            'x':0.5
        },
    xaxis_title="Countries",
    yaxis_title="Total vaccinated",
    legend_title="Total vaccinated"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1586d44a-d255-4e20-9413-71221926321d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1586d44a-d255-4e20-9413-71221926321d")) {                    Plotly.newPlot(                        "1586d44a-d255-4e20-9413-71221926321d",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>total_vaccinated_till_date=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[5694158107.0,1472306202.0,710959774.0,213769252.0,156792702.0,154688321.0,100489931.0,93641793.0,76888980.0,66983290.0,64162460.0,14969355.0,10632201.0,5070618.0,3558613.0,3430002.0,2361103.0,2043857.0,2023013.0,1232993.0,943968.0,883974.0,699241.0,696655.0,659277.0,527901.0,481476.0,469594.0,378068.0,374537.0,283407.0,241731.0,36871.0,24835.0,0.0,0.0,0.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["United States","Mexico","Canada","Cuba","Dominican Republic","Guatemala","Honduras","Nicaragua","Costa Rica","Panama","El Salvador","Jamaica","Trinidad and Tobago","Belize","Haiti","Barbados","Bahamas","Curacao","Aruba","Cayman Islands","Saint Lucia","Antigua and Barbuda","Saint Vincent and the Grenadines","Grenada","Bermuda","Dominica","Sint Maarten (Dutch part)","Turks and Caicos Islands","Greenland","Saint Kitts and Nevis","British Virgin Islands","Anguilla","Montserrat","Bonaire Sint Eustatius and Saba","United States Virgin Islands","Saint Pierre and Miquelon","Puerto Rico"],"xaxis":"x","y":[5694158107.0,1472306202.0,710959774.0,213769252.0,156792702.0,154688321.0,100489931.0,93641793.0,76888980.0,66983290.0,64162460.0,14969355.0,10632201.0,5070618.0,3558613.0,3430002.0,2361103.0,2043857.0,2023013.0,1232993.0,943968.0,883974.0,699241.0,696655.0,659277.0,527901.0,481476.0,469594.0,378068.0,374537.0,283407.0,241731.0,36871.0,24835.0,0.0,0.0,0.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666666 ...

# %%
#vaccination trend in each country
import plotly.express as px

fig = px.bar(data_grouped, x = 'month_year', y ='people_vaccinated', color = 'location')
fig.update_layout(
    title={
            'text' : "Monthly vaccination trend",
            'y':0.95,
            'x':0.5
        },
    xaxis_title="Date",
    yaxis_title="Daily Vaccinations"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="78e119ff-eeb8-4406-b091-f55b7b911ed7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78e119ff-eeb8-4406-b091-f55b7b911ed7")) {                    Plotly.newPlot(                        "78e119ff-eeb8-4406-b091-f55b7b911ed7",                        [{"alignmentgroup":"True","hovertemplate":"location=Anguilla<br>month_year=%{x}<br>people_vaccinated=%{y}<extra></extra>","legendgroup":"Anguilla","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Anguilla","offsetgroup":"Anguilla","orientation":"v","showlegend":true,"textposition":"auto","x":["2020-04-01T00:00:00","2021-04-01T00:00:00","2022-04-01T00:00:00","2020-08-01T00:00:00","2021-08-01T00:00:00","2022-08-01T00:00:00","2020-12-01T00:00:00","2021-12-01T00:00:00","2022-12-01T00:00:00","2021-02-01T00:00:00","2022-02-01T00:00:00","2023-02-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2020-07-01T00:00:00","2021-07-01T00:00:00","2022-07-01T00:00:00","2020-06-01T00:00:00","2021-06-01T00:00:00","2022-06-01T00:00:00","2020-03-01T00:00:00","2021-03-01T00:00:00","2022-03-01T00:00:00","2023-03-01T00:00:00","2020-05-01T00:00:00","2021-05-01T00:00:00","2022-05-01T00:00:00","2020-11-01T00:00:00","2021-11-01T00:00:00","2022-11-01T00:00:00","2020-10-01T00:00:00","2021-10-01T00:00:00","2022-10-01T00:00:00","2020-09-01T00:00:00","2021-09-01T00:00:00","2022-09-01T00:00:00"],"xaxis":"x","y":[0.0,6115.0,10622.0,0.0,9493.0,10846.0,0.0,10079.0,10852.0,3929.0,10370.0,10854.0,0.0,10193.0,10853.0,0.0,9428.0,10837.0,0.0,9264.0,10813.0,0.0,5348.0,10572.0,10854.0,0.0,9004.0,10746.0,0.0,9911.0,0.0,0.0,9548.0,10852.0,0.0,9498.0,10850.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=Antigua and Barbuda<br>month_year=%{x}<br>people_vaccinated=%{y}<extra></extra>","legendgroup":"Antigua and Barbuda","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Antigua and Barbuda","offsetgroup":"Antigua and Barbuda","orientation":"v","showlegend":true,"textposition":"auto","x":["2020-04-01T00:00:00","2021-04-01T00:00:00","2022-04-01T00:00:00","2020-08-01T00:00:00","2021-08-01T00:00:00","2022-08-01T00:00:00","2020-12-01T00:00:00","2021-12-01T00:00:00","2022-12-01T00:00:00","2021-02-01T00:00:00","2022-02-01T00:00:00","2023-02-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2020-07-01T00:00:00","2021-07-01T00:00:00","2022-07-01T00:00:00","2020-06-01T00:00:00","2021-06-01T00:00:00","2022-06-01T00:00:00","2020-03-01T00:00:00","2021-03-01T00:00:00","2022-03-01T00:00:00","2023-03-01T00:00:00","2020-05-01T00:00:00","2021-05-01T00:00:00","2022-05-01T00:00:00","2020-11-01T00:00:00","2021-11-01T00:00:00","2022-11-01T00:00:00","2020-10-01T00:00:00","2021-10-01T00:00:00","2022-10-01T00:00:00","2020-09-01T00:00:00","2021-09-01T00:00:00","2022-09-01T00:00:00"],"xaxis":"x","y":[0.0,29754.0,0.0,0.0,41061.0,64091.0,0.0,62283.0,0.0,0.0,63582.0,0.0,0.0,63197.0,0.0,0.0,38146.0,0.0,0.0,36432.0,64091.0,0.0,26836.0,63918.0,0.0,0.0,33463.0,63995.0,0.0,61418.0,0.0,0.0,56269.0,0.0,0.0,51148.0,64290.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"location=Puerto Rico<br>month_year=%{x}<br>people_vaccinated=%{y}<extra></extra>","legendgroup":"Puerto Rico","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Puerto Rico","offsetgroup":"Puerto Rico","orientation":"v","showlegend":true,"textposition":"auto","x":["2020-04-01T00:00:00","2021-04-01T00:00:00","2022-04-01T00:00:00","2020-08-01T00:00:00","2021-08-01T00:00:00","2020-12-01T00:00:00","2021-12-01T00:00:00","2021-02-01T00:00:00","2022-02-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2020-07-01T00:00:00","2021-07-01T00:00:00","2020-06-01T00:00:00","2021 ...

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# After analyzing the correlation between covid vaccinations and the progression of the covid 19 pandemic in North America, the following can be said:
# - the 3 countries with the highest vaccination count were the United states, Mexico and Canada.
# - when looking at covid vaccinations and new deaths over time, there is a decreasing trend of new deaths with increasing covid vaccination counts
# - when looking at covid vaccinations and new cases, there is a decreasing trend of new cases with increasing covid vaccination counts
#
#
#
# In coclusion, it can be said that vaccines did curbe the progression of the covid 19 pandemic in North America.
